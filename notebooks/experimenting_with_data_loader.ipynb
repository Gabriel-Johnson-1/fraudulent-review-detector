# %%
from data_loader import *

# %%
db = connect_to_db(verbose=1)
col = connect_to_col(db, verbose=1)
# Out:
# Connection Successful
# 11898 Total Documents in 'google_reviews' collection

# %%
df = create_google_dataframe(col)
df.head()
# Out:
#                         _id               author   city  \
# 0  69648f8bfda275b121905773           Don Larson  Provo
# 1  69648f8bfda275b121905774        Zander Kahuhu  Provo
# 2  69648f8bfda275b121905775                Sarah  Provo
# 3  69648f8bfda275b121905776  Wylieguy “Wylieguy”  Provo
# 4  69648f8bfda275b121905777       Jackson Hawker  Provo
#
#        last_modified_date  likes  \
# 0 2026-01-12 05:52:01.856      1
# 1 2026-01-12 05:52:02.368      0
# 2 2026-01-12 05:52:02.914      0
# 3 2026-01-12 05:52:03.547      0
# 4 2026-01-12 05:52:04.075      0
#
#                                      owner_responses  rating  \
# 0  Dear Don, \n\n Thank you for bringing this to ...     1.0
# 1  Zander,\n\n It sounds like your experience at ...     2.0
# 2  Sarah, \n\n I’m so sorry — it sounds like we r...     1.0
# 3  Hello,\n\nWe have reviewed your message and wa...     1.0
# 4  Jackson,\n\n It sounds like your experience at...     1.0
#
#               review_date       source  \
# ...
